# %%
import numpy as np
from numpy import genfromtxt
from scipy.stats import lognorm
import matplotlib.pyplot as plt
# fig, ax = plt.subplots(1, 1)
data = np.random.randn(1000)
# plt.hist(data, bins=np.linspace(-3,3,100), normed=True)
# plt.gca().set_xscale("log")
# plt.show()

shape,loc,scale = lognorm.fit(data)# xmin, xmax = plt.xlim(-1, 1)
x = np.linspace(-3, 3, 100)
x_log = np.logspace(0, 3, 100)
p = norm.logpdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=1)
title = "Fit results: mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)

plt.show()

# shape, loc, scale = norm.fit(data)
# pdf = sp.stats.lognorm.pdf(data, shape, loc, scale)

# plt.plot(data,pdf)

# plt.gca().set_xscale("log")
# plt.show()

# %%
data_ = norm.rvs(10.0, 2.5, size=500)
plt.hist(data, bins=25, normed=True, alpha=0.6, color='g')
plt.show()

# %%
print(data)
# Out:
# [ -1.00515549e+00  -1.59677762e+00  -1.14892391e+00  -1.83825497e+00
#    1.13928245e-01   6.12065611e-02   2.75258213e-01   5.49403873e-02
#   -9.90883950e-01   1.77725842e+00   8.71052487e-01  -5.91952967e-01
#    1.92038302e-02  -5.47404907e-01   9.49566741e-01  -1.03102802e+00
#   -1.70216328e+00   2.30711036e-01   4.54948882e-01  -7.14509131e-01
#   -3.02293932e-01  -3.33257876e-02  -7.92775737e-01   5.56793158e-01
#    5.64262787e-01   1.07109907e-01  -2.42336903e+00  -8.31464990e-01
#   -1.27862448e+00   3.72992222e-01   8.44227615e-02  -3.03075507e-01
#   -1.34732856e-01   5.32959713e-01   4.36041170e-02  -4.50496060e-01
#    3.62779846e-01  -8.30726530e-01  -3.03184008e-01  -5.16409201e-01
#    5.83078415e-01  -4.12681600e-01  -8.11888571e-01  -1.11213578e+00
#   -1.46861697e+00  -4.62848485e-01  -3.18974020e-01   6.10157566e-01
#    4.35212805e-01  -5.31077620e-01  -1.01252666e+00  -4.03739096e-01
#    4.76898994e-01  -1.01733987e+00   6.56160301e-01  -5.21737724e-02
# ...

# %%
plt.show()
